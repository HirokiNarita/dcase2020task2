# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# /home/hiroki/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})
import mlflow
from collections import defaultdict
from scipy.stats import zscore

# original library

import common as com
import pytorch_modeler as modeler
from pytorch_model import LSTM_AutoEncoder as Model
from pytorch_utils import filtered_load_model
import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
#with open("./config.yaml", 'rb') as f:
#    config = yaml.load(f)

log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')
# Out:
# /home/hiroki/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_path = INPUT_ROOT + "/dev_data"
add_dev_path = INPUT_ROOT + "/add_dev_data"
# machine type
MACHINE_TYPE = config['IO_OPTION']['MACHINE_TYPE']
machine_types = os.listdir(dev_path)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
PKL_DIR = OUTPUT_ROOT + '/pkl'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(PKL_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/working/research/dcase2020/result/2D/LSTM_VAE/config.yaml'

# %% [markdown]
# ## make path list and train/valid split

# %%
############################################################################
# make path set and train/valid split
############################################################################
'''
train_paths[machine_type]['train' or 'valid'] = path
'''
dev_train_paths = {}
add_train_paths = {}
train_paths = {}

# %%
for machine_type in machine_types:
    # dev train
    dev_train_paths = ["{}/{}/train/".format(dev_path, machine_type) + file for file in os.listdir("{}/{}/train".format(dev_path, machine_type))]
    dev_train_paths = sorted(dev_train_paths)
    # add_dev train
    add_train_paths = ["{}/{}/train/".format(add_dev_path, machine_type) + file for file in os.listdir("{}/{}/train".format(add_dev_path, machine_type))]
    add_train_paths = sorted(add_train_paths)
    # valid
    dev_valid_paths = ["{}/{}/test/".format(dev_path, machine_type) + file for file in os.listdir("{}/{}/test".format(dev_path, machine_type))]
    dev_valid_paths = sorted(dev_valid_paths)
    
    train_paths[machine_type] = {}
    train_paths[machine_type]['train'] = dev_train_paths + add_train_paths
    train_paths[machine_type]['valid'] = dev_valid_paths

# %% [raw]
# # for machine_type in machine_types:
#     # dev train
#     dev_train_all_paths = ["{}/{}/train/".format(dev_path, machine_type) + file for file in os.listdir("{}/{}/train".format(dev_path, machine_type))]
#     dev_train_all_paths = sorted(dev_train_all_paths)
#     dev_train_paths[machine_type] = {}
#     dev_train_paths[machine_type]['train'], \
#     dev_train_paths[machine_type]['valid'] = train_test_split(dev_train_all_paths,
#                                                               test_size=config['etc']['test_size'],
#                                                               shuffle=False,
#                                                              )
#     # add_dev train
#     add_train_all_paths = ["{}/{}/train/".format(add_dev_path, machine_type) + file for file in os.listdir("{}/{}/train".format(add_dev_path, machine_type))]
#     add_train_all_paths = sorted(add_train_all_paths)
#     add_train_paths[machine_type] = {}
#     add_train_paths[machine_type]['train'], \
#     add_train_paths[machine_type]['valid'] = train_test_split(add_train_all_paths,
#                                                               test_size=config['etc']['test_size'],
#                                                               shuffle=False,
#                                                              )
#     train_paths[machine_type] = {}
#     train_paths[machine_type]['train'] = dev_train_paths[machine_type]['train'] + add_train_paths[machine_type]['train']
#     train_paths[machine_type]['valid'] = dev_train_paths[machine_type]['valid'] + add_train_paths[machine_type]['valid']

# %% [markdown]
# ## training

# %%
#############################################################################
# run
#############################################################################
def run(machine_type):
    com.tic()
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(train_paths, machine_type)
    # define writer for tensorbord
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)         # debug
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    logger.info('TRAINING')
    # parameter setting
    net = Model(sample_rate=config['preprocessing']['sample_rate'],
                window_size=config['preprocessing']['window_size'],
                hop_size=config['preprocessing']['hop_size'],
                mel_bins=config['preprocessing']['mel_bins'],
                fmin=config['preprocessing']['fmin'],
                fmax=config['preprocessing']['fmax'])
    #pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_PATH'])
    #net = filtered_load_model(net, pretrained_dict)
    optimizer = optim.Adam(net.parameters())
    criterion = nn.MSELoss()
    num_epochs = config['fit']['num_epochs']
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e3, 
                                              max_lr=1e-2, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    history = modeler.train_net(net, dataloaders_dict, criterion, optimizer, scheduler, num_epochs, writer)
    # output
    model = history['model']
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    torch.save(model.state_dict(), model_out_path)
    logger.info('\n success:{0} \n'.format(machine_type) + \
                    'model_out_path ==> \n {0}'.format(model_out_path))
    #  close writer for tensorbord
    writer.close()
    #modeler.mlflow_log(history, config, machine_type, model_out_path, tb_log_dir)
    com.toc()
    return history

# %%
machine_types
# Out:
# ['fan', 'pump', 'slider', 'ToyCar', 'ToyConveyor', 'valve']

# %%
for machine_type in machine_types:
    history = run(machine_type)
    with open('{}/{}_history.pkl'.format(PKL_DIR, machine_type), 'wb') as file:
        pickle.dump(history , file)
# Out:
# 2020-11-06 01:36:31,440 - 00_train.py - INFO - TARGET MACHINE_TYPE: fan
# 2020-11-06 01:36:31,441 - 00_train.py - INFO - MAKE DATA_LOADER
# 2020-11-06 01:36:32,320 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 80.74it/s]
# 2020-11-06 01:38:04,131 - pytorch_modeler.py - INFO - Epoch 1/200:train_loss:2613.871860, valid_AUC:0.519841, valid_pAUC:0.503179
# 100%|██████████| 102/102 [01:06<00:00,  1.52it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 80.47it/s]
# 2020-11-06 01:39:33,518 - pytorch_modeler.py - INFO - Epoch 2/200:train_loss:972.887104, valid_AUC:0.517432, valid_pAUC:0.502964
# 100%|██████████| 102/102 [01:06<00:00,  1.52it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 80.19it/s]
# 2020-11-06 01:41:02,969 - pytorch_modeler.py - INFO - Epoch 3/200:train_loss:1082.674046, valid_AUC:0.519416, valid_pAUC:0.503057
# 100%|██████████| 102/102 [01:07<00:00,  1.52it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 80.48it/s]
# 2020-11-06 01:42:32,395 - pytorch_modeler.py - INFO - Epoch 4/200:train_loss:944.254542, valid_AUC:0.519549, valid_pAUC:0.502945
# 100%|██████████| 102/102 [01:06<00:00,  1.52it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.26it/s]
# 2020-11-06 01:44:01,277 - pytorch_modeler.py - INFO - Epoch 5/200:train_loss:934.089381, valid_AUC:0.519145, valid_pAUC:0.503132
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.26it/s]
# 2020-11-06 01:45:29,911 - pytorch_modeler.py - INFO - Epoch 6/200:train_loss:936.277905, valid_AUC:0.520595, valid_pAUC:0.502579
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.89it/s]
# 2020-11-06 01:46:58,552 - pytorch_modeler.py - INFO - Epoch 7/200:train_loss:1044.279046, valid_AUC:0.520349, valid_pAUC:0.502907
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.00it/s]
# 2020-11-06 01:48:27,085 - pytorch_modeler.py - INFO - Epoch 8/200:train_loss:951.202737, valid_AUC:0.519560, valid_pAUC:0.502757
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.33it/s]
# 2020-11-06 01:49:55,558 - pytorch_modeler.py - INFO - Epoch 9/200:train_loss:927.996398, valid_AUC:0.518664, valid_pAUC:0.502738
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.19it/s]
# 2020-11-06 01:51:24,078 - pytorch_modeler.py - INFO - Epoch 10/200:train_loss:898.179697, valid_AUC:0.519123, valid_pAUC:0.502204
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.00it/s]
# 2020-11-06 01:52:52,706 - pytorch_modeler.py - INFO - Epoch 11/200:train_loss:891.210141, valid_AUC:0.518936, valid_pAUC:0.502279
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.22it/s]
# 2020-11-06 01:54:21,218 - pytorch_modeler.py - INFO - Epoch 12/200:train_loss:884.401333, valid_AUC:0.519171, valid_pAUC:0.502598
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.91it/s]
# 2020-11-06 01:55:49,794 - pytorch_modeler.py - INFO - Epoch 13/200:train_loss:877.574936, valid_AUC:0.518993, valid_pAUC:0.502598
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.83it/s]
# 2020-11-06 01:57:18,337 - pytorch_modeler.py - INFO - Epoch 14/200:train_loss:870.859612, valid_AUC:0.520552, valid_pAUC:0.502542
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.12it/s]
# 2020-11-06 01:58:46,951 - pytorch_modeler.py - INFO - Epoch 15/200:train_loss:864.159945, valid_AUC:0.518533, valid_pAUC:0.502635
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.15it/s]
# 2020-11-06 02:00:15,478 - pytorch_modeler.py - INFO - Epoch 16/200:train_loss:857.669316, valid_AUC:0.518546, valid_pAUC:0.502710
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.20it/s]
# 2020-11-06 02:01:44,076 - pytorch_modeler.py - INFO - Epoch 17/200:train_loss:1385078784.985019, valid_AUC:0.533193, valid_pAUC:0.510354
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.22it/s]
# 2020-11-06 02:03:12,595 - pytorch_modeler.py - INFO - Epoch 18/200:train_loss:40774.807296, valid_AUC:0.549298, valid_pAUC:0.501444
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.23it/s]
# 2020-11-06 02:04:41,133 - pytorch_modeler.py - INFO - Epoch 19/200:train_loss:5192.259081, valid_AUC:0.541805, valid_pAUC:0.502654
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 81.99it/s]
# 2020-11-06 02:06:09,767 - pytorch_modeler.py - INFO - Epoch 20/200:train_loss:3580.366236, valid_AUC:0.536689, valid_pAUC:0.502204
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.29it/s]
# 2020-11-06 02:07:38,235 - pytorch_modeler.py - INFO - Epoch 21/200:train_loss:2833.135294, valid_AUC:0.527910, valid_pAUC:0.501819
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.01it/s]
# 2020-11-06 02:09:06,755 - pytorch_modeler.py - INFO - Epoch 22/200:train_loss:2442.284047, valid_AUC:0.534304, valid_pAUC:0.502270
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.37it/s]
# 2020-11-06 02:10:35,231 - pytorch_modeler.py - INFO - Epoch 23/200:train_loss:2296.682575, valid_AUC:0.531459, valid_pAUC:0.502307
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.23it/s]
# 2020-11-06 02:12:03,721 - pytorch_modeler.py - INFO - Epoch 24/200:train_loss:1816.613677, valid_AUC:0.527455, valid_pAUC:0.502654
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.26it/s]
# 2020-11-06 02:13:32,181 - pytorch_modeler.py - INFO - Epoch 25/200:train_loss:1758.174311, valid_AUC:0.523937, valid_pAUC:0.502035
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.76it/s]
# 2020-11-06 02:15:00,782 - pytorch_modeler.py - INFO - Epoch 26/200:train_loss:1595.280261, valid_AUC:0.526326, valid_pAUC:0.502251
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.44it/s]
# 2020-11-06 02:16:29,185 - pytorch_modeler.py - INFO - Epoch 27/200:train_loss:1527.955949, valid_AUC:0.525385, valid_pAUC:0.502391
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.23it/s]
# 2020-11-06 02:17:57,723 - pytorch_modeler.py - INFO - Epoch 28/200:train_loss:1384.827554, valid_AUC:0.527457, valid_pAUC:0.502401
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.28it/s]
# 2020-11-06 02:19:26,210 - pytorch_modeler.py - INFO - Epoch 29/200:train_loss:1445.611130, valid_AUC:0.523060, valid_pAUC:0.502551
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.87it/s]
# 2020-11-06 02:20:54,774 - pytorch_modeler.py - INFO - Epoch 30/200:train_loss:1368.409762, valid_AUC:0.522746, valid_pAUC:0.502588
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.31it/s]
# 2020-11-06 02:22:23,187 - pytorch_modeler.py - INFO - Epoch 31/200:train_loss:1191.479302, valid_AUC:0.527420, valid_pAUC:0.502523
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.05it/s]
# 2020-11-06 02:23:51,779 - pytorch_modeler.py - INFO - Epoch 32/200:train_loss:1146.061384, valid_AUC:0.526356, valid_pAUC:0.502279
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.33it/s]
# 2020-11-06 02:25:20,280 - pytorch_modeler.py - INFO - Epoch 33/200:train_loss:1093.501213, valid_AUC:0.523223, valid_pAUC:0.502176
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.85it/s]
# 2020-11-06 02:26:48,896 - pytorch_modeler.py - INFO - Epoch 34/200:train_loss:1071.482500, valid_AUC:0.525175, valid_pAUC:0.502588
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.33it/s]
# 2020-11-06 02:28:17,339 - pytorch_modeler.py - INFO - Epoch 35/200:train_loss:1064.855094, valid_AUC:0.525934, valid_pAUC:0.502842
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.38it/s]
# 2020-11-06 02:29:45,806 - pytorch_modeler.py - INFO - Epoch 36/200:train_loss:1020.896724, valid_AUC:0.529305, valid_pAUC:0.502579
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.24it/s]
# 2020-11-06 02:31:14,289 - pytorch_modeler.py - INFO - Epoch 37/200:train_loss:977.541391, valid_AUC:0.522096, valid_pAUC:0.502063
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.94it/s]
# 2020-11-06 02:32:42,829 - pytorch_modeler.py - INFO - Epoch 38/200:train_loss:961.428130, valid_AUC:0.525934, valid_pAUC:0.502682
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 02:34:11,272 - pytorch_modeler.py - INFO - Epoch 39/200:train_loss:960.328455, valid_AUC:0.525310, valid_pAUC:0.503611
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.25it/s]
# 2020-11-06 02:35:39,760 - pytorch_modeler.py - INFO - Epoch 40/200:train_loss:904.976116, valid_AUC:0.520406, valid_pAUC:0.502082
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.35it/s]
# 2020-11-06 02:37:08,319 - pytorch_modeler.py - INFO - Epoch 41/200:train_loss:894.884881, valid_AUC:0.523257, valid_pAUC:0.503245
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.30it/s]
# 2020-11-06 02:38:36,867 - pytorch_modeler.py - INFO - Epoch 42/200:train_loss:866.777411, valid_AUC:0.522675, valid_pAUC:0.503029
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.42it/s]
# 2020-11-06 02:40:05,404 - pytorch_modeler.py - INFO - Epoch 43/200:train_loss:857.516491, valid_AUC:0.522619, valid_pAUC:0.503076
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.08it/s]
# 2020-11-06 02:41:33,971 - pytorch_modeler.py - INFO - Epoch 44/200:train_loss:836.893086, valid_AUC:0.523473, valid_pAUC:0.502654
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.12it/s]
# 2020-11-06 02:43:02,554 - pytorch_modeler.py - INFO - Epoch 45/200:train_loss:813.913130, valid_AUC:0.524224, valid_pAUC:0.502710
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.21it/s]
# 2020-11-06 02:44:31,041 - pytorch_modeler.py - INFO - Epoch 46/200:train_loss:801.425455, valid_AUC:0.527176, valid_pAUC:0.502241
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.46it/s]
# 2020-11-06 02:45:59,530 - pytorch_modeler.py - INFO - Epoch 47/200:train_loss:846.714159, valid_AUC:0.527806, valid_pAUC:0.501857
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.29it/s]
# 2020-11-06 02:47:28,085 - pytorch_modeler.py - INFO - Epoch 48/200:train_loss:788.068434, valid_AUC:0.516916, valid_pAUC:0.501885
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.93it/s]
# 2020-11-06 02:48:56,614 - pytorch_modeler.py - INFO - Epoch 49/200:train_loss:762.116244, valid_AUC:0.523562, valid_pAUC:0.502513
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.06it/s]
# 2020-11-06 02:50:25,170 - pytorch_modeler.py - INFO - Epoch 50/200:train_loss:765.314333, valid_AUC:0.521579, valid_pAUC:0.503057
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.52it/s]
# 2020-11-06 02:51:53,602 - pytorch_modeler.py - INFO - Epoch 51/200:train_loss:753.216648, valid_AUC:0.518109, valid_pAUC:0.503095
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.27it/s]
# 2020-11-06 02:53:22,080 - pytorch_modeler.py - INFO - Epoch 52/200:train_loss:724.611982, valid_AUC:0.524116, valid_pAUC:0.502420
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.02it/s]
# 2020-11-06 02:54:50,662 - pytorch_modeler.py - INFO - Epoch 53/200:train_loss:721.232413, valid_AUC:0.521270, valid_pAUC:0.502879
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.23it/s]
# 2020-11-06 02:56:19,176 - pytorch_modeler.py - INFO - Epoch 54/200:train_loss:719.313949, valid_AUC:0.520880, valid_pAUC:0.502429
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.44it/s]
# 2020-11-06 02:57:47,572 - pytorch_modeler.py - INFO - Epoch 55/200:train_loss:700.231865, valid_AUC:0.523202, valid_pAUC:0.502729
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.03it/s]
# 2020-11-06 02:59:16,258 - pytorch_modeler.py - INFO - Epoch 56/200:train_loss:690.400930, valid_AUC:0.523824, valid_pAUC:0.502363
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.60it/s]
# 2020-11-06 03:00:44,913 - pytorch_modeler.py - INFO - Epoch 57/200:train_loss:689.810170, valid_AUC:0.519968, valid_pAUC:0.502438
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.19it/s]
# 2020-11-06 03:02:13,370 - pytorch_modeler.py - INFO - Epoch 58/200:train_loss:673.916734, valid_AUC:0.520397, valid_pAUC:0.502504
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.42it/s]
# 2020-11-06 03:03:41,844 - pytorch_modeler.py - INFO - Epoch 59/200:train_loss:696.700502, valid_AUC:0.522363, valid_pAUC:0.503104
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 03:05:10,314 - pytorch_modeler.py - INFO - Epoch 60/200:train_loss:650.975958, valid_AUC:0.517801, valid_pAUC:0.502870
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.27it/s]
# 2020-11-06 03:06:38,746 - pytorch_modeler.py - INFO - Epoch 61/200:train_loss:647.796538, valid_AUC:0.521489, valid_pAUC:0.502823
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.03it/s]
# 2020-11-06 03:08:07,253 - pytorch_modeler.py - INFO - Epoch 62/200:train_loss:641.625989, valid_AUC:0.521679, valid_pAUC:0.502345
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.45it/s]
# 2020-11-06 03:09:35,684 - pytorch_modeler.py - INFO - Epoch 63/200:train_loss:636.022730, valid_AUC:0.519114, valid_pAUC:0.502626
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.88it/s]
# 2020-11-06 03:11:04,206 - pytorch_modeler.py - INFO - Epoch 64/200:train_loss:624.973692, valid_AUC:0.522973, valid_pAUC:0.502560
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.36it/s]
# 2020-11-06 03:12:32,643 - pytorch_modeler.py - INFO - Epoch 65/200:train_loss:620.298569, valid_AUC:0.523738, valid_pAUC:0.502814
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 03:14:01,063 - pytorch_modeler.py - INFO - Epoch 66/200:train_loss:610.590412, valid_AUC:0.520870, valid_pAUC:0.502354
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.30it/s]
# 2020-11-06 03:15:29,483 - pytorch_modeler.py - INFO - Epoch 67/200:train_loss:604.408035, valid_AUC:0.520836, valid_pAUC:0.502101
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.73it/s]
# 2020-11-06 03:16:58,016 - pytorch_modeler.py - INFO - Epoch 68/200:train_loss:597.627288, valid_AUC:0.520811, valid_pAUC:0.501697
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.43it/s]
# 2020-11-06 03:18:26,419 - pytorch_modeler.py - INFO - Epoch 69/200:train_loss:593.823666, valid_AUC:0.518152, valid_pAUC:0.503123
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.22it/s]
# 2020-11-06 03:19:54,956 - pytorch_modeler.py - INFO - Epoch 70/200:train_loss:588.443589, valid_AUC:0.520606, valid_pAUC:0.502626
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.19it/s]
# 2020-11-06 03:21:23,428 - pytorch_modeler.py - INFO - Epoch 71/200:train_loss:578.961112, valid_AUC:0.517395, valid_pAUC:0.502485
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 81.98it/s]
# 2020-11-06 03:22:51,886 - pytorch_modeler.py - INFO - Epoch 72/200:train_loss:575.938532, valid_AUC:0.520809, valid_pAUC:0.502448
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.14it/s]
# 2020-11-06 03:24:20,331 - pytorch_modeler.py - INFO - Epoch 73/200:train_loss:570.638957, valid_AUC:0.519457, valid_pAUC:0.502345
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.91it/s]
# 2020-11-06 03:25:48,960 - pytorch_modeler.py - INFO - Epoch 74/200:train_loss:561.935944, valid_AUC:0.519072, valid_pAUC:0.502842
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.42it/s]
# 2020-11-06 03:27:17,466 - pytorch_modeler.py - INFO - Epoch 75/200:train_loss:558.060288, valid_AUC:0.515857, valid_pAUC:0.502335
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.79it/s]
# 2020-11-06 03:28:45,995 - pytorch_modeler.py - INFO - Epoch 76/200:train_loss:551.148153, valid_AUC:0.514792, valid_pAUC:0.502176
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.29it/s]
# 2020-11-06 03:30:14,472 - pytorch_modeler.py - INFO - Epoch 77/200:train_loss:544.421012, valid_AUC:0.518625, valid_pAUC:0.502607
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.17it/s]
# 2020-11-06 03:31:42,990 - pytorch_modeler.py - INFO - Epoch 78/200:train_loss:541.993783, valid_AUC:0.518546, valid_pAUC:0.503020
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.14it/s]
# 2020-11-06 03:33:11,462 - pytorch_modeler.py - INFO - Epoch 79/200:train_loss:534.448736, valid_AUC:0.519109, valid_pAUC:0.502213
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.91it/s]
# 2020-11-06 03:34:40,027 - pytorch_modeler.py - INFO - Epoch 80/200:train_loss:528.794736, valid_AUC:0.519429, valid_pAUC:0.502148
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.36it/s]
# 2020-11-06 03:36:08,391 - pytorch_modeler.py - INFO - Epoch 81/200:train_loss:523.851997, valid_AUC:0.518446, valid_pAUC:0.502504
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.15it/s]
# 2020-11-06 03:37:36,892 - pytorch_modeler.py - INFO - Epoch 82/200:train_loss:520.002756, valid_AUC:0.516974, valid_pAUC:0.502926
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.95it/s]
# 2020-11-06 03:39:05,381 - pytorch_modeler.py - INFO - Epoch 83/200:train_loss:516.761677, valid_AUC:0.517843, valid_pAUC:0.502635
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.43it/s]
# 2020-11-06 03:40:33,696 - pytorch_modeler.py - INFO - Epoch 84/200:train_loss:508.967070, valid_AUC:0.520371, valid_pAUC:0.502785
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.21it/s]
# 2020-11-06 03:42:02,083 - pytorch_modeler.py - INFO - Epoch 85/200:train_loss:503.843119, valid_AUC:0.516957, valid_pAUC:0.503020
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.09it/s]
# 2020-11-06 03:43:30,589 - pytorch_modeler.py - INFO - Epoch 86/200:train_loss:500.212817, valid_AUC:0.518159, valid_pAUC:0.502692
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.12it/s]
# 2020-11-06 03:44:58,998 - pytorch_modeler.py - INFO - Epoch 87/200:train_loss:493.799464, valid_AUC:0.517461, valid_pAUC:0.502645
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.16it/s]
# 2020-11-06 03:46:27,465 - pytorch_modeler.py - INFO - Epoch 88/200:train_loss:490.838382, valid_AUC:0.516411, valid_pAUC:0.502429
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.26it/s]
# 2020-11-06 03:47:55,799 - pytorch_modeler.py - INFO - Epoch 89/200:train_loss:485.531954, valid_AUC:0.518566, valid_pAUC:0.502560
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.12it/s]
# 2020-11-06 03:49:24,266 - pytorch_modeler.py - INFO - Epoch 90/200:train_loss:482.808993, valid_AUC:0.518193, valid_pAUC:0.501688
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.91it/s]
# 2020-11-06 03:50:52,843 - pytorch_modeler.py - INFO - Epoch 91/200:train_loss:475.844835, valid_AUC:0.518815, valid_pAUC:0.502448
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.07it/s]
# 2020-11-06 03:52:21,254 - pytorch_modeler.py - INFO - Epoch 92/200:train_loss:471.403485, valid_AUC:0.518918, valid_pAUC:0.502860
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.35it/s]
# 2020-11-06 03:53:49,669 - pytorch_modeler.py - INFO - Epoch 93/200:train_loss:466.370414, valid_AUC:0.519594, valid_pAUC:0.502485
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.26it/s]
# 2020-11-06 03:55:18,283 - pytorch_modeler.py - INFO - Epoch 94/200:train_loss:463.489969, valid_AUC:0.518457, valid_pAUC:0.502542
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.87it/s]
# 2020-11-06 03:56:46,818 - pytorch_modeler.py - INFO - Epoch 95/200:train_loss:458.531886, valid_AUC:0.519316, valid_pAUC:0.502673
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.38it/s]
# 2020-11-06 03:58:15,246 - pytorch_modeler.py - INFO - Epoch 96/200:train_loss:453.357625, valid_AUC:0.517839, valid_pAUC:0.502551
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.25it/s]
# 2020-11-06 03:59:43,708 - pytorch_modeler.py - INFO - Epoch 97/200:train_loss:450.436042, valid_AUC:0.515821, valid_pAUC:0.502729
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.05it/s]
# 2020-11-06 04:01:12,218 - pytorch_modeler.py - INFO - Epoch 98/200:train_loss:444.556334, valid_AUC:0.516762, valid_pAUC:0.502767
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.53it/s]
# 2020-11-06 04:02:40,585 - pytorch_modeler.py - INFO - Epoch 99/200:train_loss:441.649572, valid_AUC:0.518774, valid_pAUC:0.502579
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.28it/s]
# 2020-11-06 04:04:09,018 - pytorch_modeler.py - INFO - Epoch 100/200:train_loss:437.512547, valid_AUC:0.517919, valid_pAUC:0.502410
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.28it/s]
# 2020-11-06 04:05:37,459 - pytorch_modeler.py - INFO - Epoch 101/200:train_loss:433.010785, valid_AUC:0.518013, valid_pAUC:0.502551
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.89it/s]
# 2020-11-06 04:07:05,980 - pytorch_modeler.py - INFO - Epoch 102/200:train_loss:428.012770, valid_AUC:0.518484, valid_pAUC:0.502513
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.30it/s]
# 2020-11-06 04:08:34,428 - pytorch_modeler.py - INFO - Epoch 103/200:train_loss:423.827008, valid_AUC:0.517869, valid_pAUC:0.502635
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.08it/s]
# 2020-11-06 04:10:02,949 - pytorch_modeler.py - INFO - Epoch 104/200:train_loss:420.203276, valid_AUC:0.517395, valid_pAUC:0.502617
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.36it/s]
# 2020-11-06 04:11:31,275 - pytorch_modeler.py - INFO - Epoch 105/200:train_loss:415.944448, valid_AUC:0.518177, valid_pAUC:0.502663
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.91it/s]
# 2020-11-06 04:12:59,774 - pytorch_modeler.py - INFO - Epoch 106/200:train_loss:412.598127, valid_AUC:0.517694, valid_pAUC:0.502588
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.33it/s]
# 2020-11-06 04:14:28,160 - pytorch_modeler.py - INFO - Epoch 107/200:train_loss:408.233252, valid_AUC:0.516800, valid_pAUC:0.502429
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 04:15:56,707 - pytorch_modeler.py - INFO - Epoch 108/200:train_loss:404.446877, valid_AUC:0.518329, valid_pAUC:0.502513
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.10it/s]
# 2020-11-06 04:17:25,144 - pytorch_modeler.py - INFO - Epoch 109/200:train_loss:400.155502, valid_AUC:0.517564, valid_pAUC:0.502467
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.69it/s]
# 2020-11-06 04:18:53,740 - pytorch_modeler.py - INFO - Epoch 110/200:train_loss:395.961935, valid_AUC:0.518343, valid_pAUC:0.502720
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.56it/s]
# 2020-11-06 04:20:22,117 - pytorch_modeler.py - INFO - Epoch 111/200:train_loss:392.786319, valid_AUC:0.516732, valid_pAUC:0.501669
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.10it/s]
# 2020-11-06 04:21:50,556 - pytorch_modeler.py - INFO - Epoch 112/200:train_loss:388.712626, valid_AUC:0.518706, valid_pAUC:0.502682
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.41it/s]
# 2020-11-06 04:23:18,963 - pytorch_modeler.py - INFO - Epoch 113/200:train_loss:385.440601, valid_AUC:0.516834, valid_pAUC:0.502476
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.01it/s]
# 2020-11-06 04:24:47,410 - pytorch_modeler.py - INFO - Epoch 114/200:train_loss:381.032478, valid_AUC:0.517769, valid_pAUC:0.502579
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.29it/s]
# 2020-11-06 04:26:15,850 - pytorch_modeler.py - INFO - Epoch 115/200:train_loss:377.100271, valid_AUC:0.517552, valid_pAUC:0.502682
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.21it/s]
# 2020-11-06 04:27:44,267 - pytorch_modeler.py - INFO - Epoch 116/200:train_loss:374.137826, valid_AUC:0.517647, valid_pAUC:0.502495
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.44it/s]
# 2020-11-06 04:29:12,690 - pytorch_modeler.py - INFO - Epoch 117/200:train_loss:369.869661, valid_AUC:0.518084, valid_pAUC:0.502551
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.27it/s]
# 2020-11-06 04:30:41,173 - pytorch_modeler.py - INFO - Epoch 118/200:train_loss:366.000795, valid_AUC:0.518439, valid_pAUC:0.502626
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.45it/s]
# 2020-11-06 04:32:09,502 - pytorch_modeler.py - INFO - Epoch 119/200:train_loss:362.628010, valid_AUC:0.517828, valid_pAUC:0.502682
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.46it/s]
# 2020-11-06 04:33:37,902 - pytorch_modeler.py - INFO - Epoch 120/200:train_loss:358.622332, valid_AUC:0.518161, valid_pAUC:0.502560
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.83it/s]
# 2020-11-06 04:35:06,375 - pytorch_modeler.py - INFO - Epoch 121/200:train_loss:355.293754, valid_AUC:0.518393, valid_pAUC:0.502617
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 81.96it/s]
# 2020-11-06 04:36:34,913 - pytorch_modeler.py - INFO - Epoch 122/200:train_loss:351.634904, valid_AUC:0.517744, valid_pAUC:0.502542
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.44it/s]
# 2020-11-06 04:38:03,246 - pytorch_modeler.py - INFO - Epoch 123/200:train_loss:348.386435, valid_AUC:0.517986, valid_pAUC:0.502663
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.20it/s]
# 2020-11-06 04:39:31,732 - pytorch_modeler.py - INFO - Epoch 124/200:train_loss:344.409599, valid_AUC:0.518342, valid_pAUC:0.502570
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.89it/s]
# 2020-11-06 04:41:00,183 - pytorch_modeler.py - INFO - Epoch 125/200:train_loss:341.289741, valid_AUC:0.517242, valid_pAUC:0.502542
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.24it/s]
# 2020-11-06 04:42:28,689 - pytorch_modeler.py - INFO - Epoch 126/200:train_loss:337.478189, valid_AUC:0.518396, valid_pAUC:0.502785
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.12it/s]
# 2020-11-06 04:43:57,052 - pytorch_modeler.py - INFO - Epoch 127/200:train_loss:334.141846, valid_AUC:0.517630, valid_pAUC:0.502635
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.12it/s]
# 2020-11-06 04:45:25,525 - pytorch_modeler.py - INFO - Epoch 128/200:train_loss:330.454306, valid_AUC:0.518112, valid_pAUC:0.502635
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.15it/s]
# 2020-11-06 04:46:53,925 - pytorch_modeler.py - INFO - Epoch 129/200:train_loss:326.982653, valid_AUC:0.517206, valid_pAUC:0.502598
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.10it/s]
# 2020-11-06 04:48:22,412 - pytorch_modeler.py - INFO - Epoch 130/200:train_loss:323.926231, valid_AUC:0.517473, valid_pAUC:0.502617
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 04:49:50,781 - pytorch_modeler.py - INFO - Epoch 131/200:train_loss:320.394564, valid_AUC:0.517934, valid_pAUC:0.502504
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.28it/s]
# 2020-11-06 04:51:19,205 - pytorch_modeler.py - INFO - Epoch 132/200:train_loss:316.883253, valid_AUC:0.518102, valid_pAUC:0.502570
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.87it/s]
# 2020-11-06 04:52:47,688 - pytorch_modeler.py - INFO - Epoch 133/200:train_loss:313.595771, valid_AUC:0.518359, valid_pAUC:0.502523
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 81.96it/s]
# 2020-11-06 04:54:16,137 - pytorch_modeler.py - INFO - Epoch 134/200:train_loss:310.298552, valid_AUC:0.518086, valid_pAUC:0.502560
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.40it/s]
# 2020-11-06 04:55:44,495 - pytorch_modeler.py - INFO - Epoch 135/200:train_loss:307.100591, valid_AUC:0.518166, valid_pAUC:0.502588
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.19it/s]
# 2020-11-06 04:57:12,949 - pytorch_modeler.py - INFO - Epoch 136/200:train_loss:303.766094, valid_AUC:0.517824, valid_pAUC:0.502551
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.23it/s]
# 2020-11-06 04:58:41,286 - pytorch_modeler.py - INFO - Epoch 137/200:train_loss:300.458948, valid_AUC:0.517402, valid_pAUC:0.502560
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.27it/s]
# 2020-11-06 05:00:09,700 - pytorch_modeler.py - INFO - Epoch 138/200:train_loss:297.424898, valid_AUC:0.518170, valid_pAUC:0.502598
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.22it/s]
# 2020-11-06 05:01:38,075 - pytorch_modeler.py - INFO - Epoch 139/200:train_loss:293.968396, valid_AUC:0.517543, valid_pAUC:0.502617
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.02it/s]
# 2020-11-06 05:03:06,504 - pytorch_modeler.py - INFO - Epoch 140/200:train_loss:291.013035, valid_AUC:0.518104, valid_pAUC:0.502551
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 05:04:34,939 - pytorch_modeler.py - INFO - Epoch 141/200:train_loss:287.844238, valid_AUC:0.518516, valid_pAUC:0.502542
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.09it/s]
# 2020-11-06 05:06:03,315 - pytorch_modeler.py - INFO - Epoch 142/200:train_loss:284.539438, valid_AUC:0.517662, valid_pAUC:0.502570
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.38it/s]
# 2020-11-06 05:07:31,685 - pytorch_modeler.py - INFO - Epoch 143/200:train_loss:281.489957, valid_AUC:0.519211, valid_pAUC:0.502560
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.95it/s]
# 2020-11-06 05:09:00,145 - pytorch_modeler.py - INFO - Epoch 144/200:train_loss:278.486117, valid_AUC:0.517985, valid_pAUC:0.502795
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.16it/s]
# 2020-11-06 05:10:28,595 - pytorch_modeler.py - INFO - Epoch 145/200:train_loss:275.258054, valid_AUC:0.517810, valid_pAUC:0.502260
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 81.98it/s]
# 2020-11-06 05:11:57,063 - pytorch_modeler.py - INFO - Epoch 146/200:train_loss:272.306427, valid_AUC:0.517635, valid_pAUC:0.502438
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.44it/s]
# 2020-11-06 05:13:25,511 - pytorch_modeler.py - INFO - Epoch 147/200:train_loss:269.249563, valid_AUC:0.517607, valid_pAUC:0.502542
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.45it/s]
# 2020-11-06 05:14:54,092 - pytorch_modeler.py - INFO - Epoch 148/200:train_loss:266.071538, valid_AUC:0.518879, valid_pAUC:0.502635
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.34it/s]
# 2020-11-06 05:16:22,418 - pytorch_modeler.py - INFO - Epoch 149/200:train_loss:263.055441, valid_AUC:0.517725, valid_pAUC:0.502588
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.18it/s]
# 2020-11-06 05:17:50,951 - pytorch_modeler.py - INFO - Epoch 150/200:train_loss:260.116361, valid_AUC:0.517667, valid_pAUC:0.502570
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.12it/s]
# 2020-11-06 05:19:19,356 - pytorch_modeler.py - INFO - Epoch 151/200:train_loss:257.173412, valid_AUC:0.517767, valid_pAUC:0.502598
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.66it/s]
# 2020-11-06 05:20:47,898 - pytorch_modeler.py - INFO - Epoch 152/200:train_loss:254.305452, valid_AUC:0.518184, valid_pAUC:0.502692
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 05:22:16,202 - pytorch_modeler.py - INFO - Epoch 153/200:train_loss:251.315572, valid_AUC:0.516819, valid_pAUC:0.502588
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.16it/s]
# 2020-11-06 05:23:44,543 - pytorch_modeler.py - INFO - Epoch 154/200:train_loss:248.364047, valid_AUC:0.518175, valid_pAUC:0.502598
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.20it/s]
# 2020-11-06 05:25:12,948 - pytorch_modeler.py - INFO - Epoch 155/200:train_loss:245.574537, valid_AUC:0.517741, valid_pAUC:0.502513
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.30it/s]
# 2020-11-06 05:26:41,395 - pytorch_modeler.py - INFO - Epoch 156/200:train_loss:242.771382, valid_AUC:0.517466, valid_pAUC:0.502598
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.14it/s]
# 2020-11-06 05:28:09,735 - pytorch_modeler.py - INFO - Epoch 157/200:train_loss:239.811099, valid_AUC:0.518109, valid_pAUC:0.502645
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.86it/s]
# 2020-11-06 05:29:38,214 - pytorch_modeler.py - INFO - Epoch 158/200:train_loss:236.991907, valid_AUC:0.517578, valid_pAUC:0.502584
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.42it/s]
# 2020-11-06 05:31:06,601 - pytorch_modeler.py - INFO - Epoch 159/200:train_loss:234.297949, valid_AUC:0.517901, valid_pAUC:0.502645
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.11it/s]
# 2020-11-06 05:32:35,014 - pytorch_modeler.py - INFO - Epoch 160/200:train_loss:231.290785, valid_AUC:0.517072, valid_pAUC:0.502570
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.35it/s]
# 2020-11-06 05:34:03,310 - pytorch_modeler.py - INFO - Epoch 161/200:train_loss:228.668276, valid_AUC:0.517735, valid_pAUC:0.502570
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.33it/s]
# 2020-11-06 05:35:31,712 - pytorch_modeler.py - INFO - Epoch 162/200:train_loss:225.931424, valid_AUC:0.517641, valid_pAUC:0.502588
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.90it/s]
# 2020-11-06 05:37:00,213 - pytorch_modeler.py - INFO - Epoch 163/200:train_loss:223.189445, valid_AUC:0.517486, valid_pAUC:0.502607
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.11it/s]
# 2020-11-06 05:38:28,701 - pytorch_modeler.py - INFO - Epoch 164/200:train_loss:220.463595, valid_AUC:0.518099, valid_pAUC:0.502635
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.42it/s]
# 2020-11-06 05:39:57,107 - pytorch_modeler.py - INFO - Epoch 165/200:train_loss:217.825450, valid_AUC:0.517368, valid_pAUC:0.502879
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.18it/s]
# 2020-11-06 05:41:25,493 - pytorch_modeler.py - INFO - Epoch 166/200:train_loss:215.184726, valid_AUC:0.518476, valid_pAUC:0.502663
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.09it/s]
# 2020-11-06 05:42:53,932 - pytorch_modeler.py - INFO - Epoch 167/200:train_loss:212.455341, valid_AUC:0.517366, valid_pAUC:0.502588
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.25it/s]
# 2020-11-06 05:44:22,346 - pytorch_modeler.py - INFO - Epoch 168/200:train_loss:209.887235, valid_AUC:0.518059, valid_pAUC:0.502607
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.25it/s]
# 2020-11-06 05:45:50,747 - pytorch_modeler.py - INFO - Epoch 169/200:train_loss:207.232918, valid_AUC:0.518236, valid_pAUC:0.502663
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 81.98it/s]
# 2020-11-06 05:47:19,176 - pytorch_modeler.py - INFO - Epoch 170/200:train_loss:204.678295, valid_AUC:0.517316, valid_pAUC:0.502532
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.13it/s]
# 2020-11-06 05:48:47,638 - pytorch_modeler.py - INFO - Epoch 171/200:train_loss:202.054203, valid_AUC:0.517663, valid_pAUC:0.502870
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.13it/s]
# 2020-11-06 05:50:16,045 - pytorch_modeler.py - INFO - Epoch 172/200:train_loss:199.574833, valid_AUC:0.517694, valid_pAUC:0.502607
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.34it/s]
# 2020-11-06 05:51:44,375 - pytorch_modeler.py - INFO - Epoch 173/200:train_loss:197.032733, valid_AUC:0.517546, valid_pAUC:0.502645
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.13it/s]
# 2020-11-06 05:53:12,847 - pytorch_modeler.py - INFO - Epoch 174/200:train_loss:194.585959, valid_AUC:0.517538, valid_pAUC:0.502673
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 05:54:41,176 - pytorch_modeler.py - INFO - Epoch 175/200:train_loss:192.000256, valid_AUC:0.517505, valid_pAUC:0.502645
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.03it/s]
# 2020-11-06 05:56:09,822 - pytorch_modeler.py - INFO - Epoch 176/200:train_loss:189.613612, valid_AUC:0.516074, valid_pAUC:0.502443
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.30it/s]
# 2020-11-06 05:57:38,221 - pytorch_modeler.py - INFO - Epoch 177/200:train_loss:187.077446, valid_AUC:0.517222, valid_pAUC:0.502710
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.07it/s]
# 2020-11-06 05:59:06,671 - pytorch_modeler.py - INFO - Epoch 178/200:train_loss:184.828882, valid_AUC:0.517821, valid_pAUC:0.502663
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.25it/s]
# 2020-11-06 06:00:35,149 - pytorch_modeler.py - INFO - Epoch 179/200:train_loss:182.209347, valid_AUC:0.517400, valid_pAUC:0.502776
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 06:02:03,595 - pytorch_modeler.py - INFO - Epoch 180/200:train_loss:179.879718, valid_AUC:0.516787, valid_pAUC:0.502654
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.22it/s]
# 2020-11-06 06:03:32,018 - pytorch_modeler.py - INFO - Epoch 181/200:train_loss:177.514043, valid_AUC:0.517493, valid_pAUC:0.502720
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.59it/s]
# 2020-11-06 06:05:00,565 - pytorch_modeler.py - INFO - Epoch 182/200:train_loss:175.161560, valid_AUC:0.515993, valid_pAUC:0.502645
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.49it/s]
# 2020-11-06 06:06:28,894 - pytorch_modeler.py - INFO - Epoch 183/200:train_loss:172.828303, valid_AUC:0.517144, valid_pAUC:0.502748
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.23it/s]
# 2020-11-06 06:07:57,314 - pytorch_modeler.py - INFO - Epoch 184/200:train_loss:170.514051, valid_AUC:0.517643, valid_pAUC:0.502701
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.30it/s]
# 2020-11-06 06:09:25,640 - pytorch_modeler.py - INFO - Epoch 185/200:train_loss:168.185481, valid_AUC:0.516924, valid_pAUC:0.502682
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.92it/s]
# 2020-11-06 06:10:54,128 - pytorch_modeler.py - INFO - Epoch 186/200:train_loss:165.934756, valid_AUC:0.517413, valid_pAUC:0.502720
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 06:12:22,513 - pytorch_modeler.py - INFO - Epoch 187/200:train_loss:163.715710, valid_AUC:0.516953, valid_pAUC:0.502692
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.01it/s]
# 2020-11-06 06:13:50,953 - pytorch_modeler.py - INFO - Epoch 188/200:train_loss:161.417100, valid_AUC:0.517596, valid_pAUC:0.502767
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.32it/s]
# 2020-11-06 06:15:19,436 - pytorch_modeler.py - INFO - Epoch 189/200:train_loss:159.318852, valid_AUC:0.516980, valid_pAUC:0.502738
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:22<00:00, 81.92it/s]
# 2020-11-06 06:16:47,852 - pytorch_modeler.py - INFO - Epoch 190/200:train_loss:157.058188, valid_AUC:0.517432, valid_pAUC:0.502682
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.42it/s]
# 2020-11-06 06:18:16,208 - pytorch_modeler.py - INFO - Epoch 191/200:train_loss:154.837548, valid_AUC:0.516930, valid_pAUC:0.502710
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.38it/s]
# 2020-11-06 06:19:44,597 - pytorch_modeler.py - INFO - Epoch 192/200:train_loss:152.669887, valid_AUC:0.517037, valid_pAUC:0.502663
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.22it/s]
# 2020-11-06 06:21:13,021 - pytorch_modeler.py - INFO - Epoch 193/200:train_loss:150.656300, valid_AUC:0.516673, valid_pAUC:0.502738
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 81.99it/s]
# 2020-11-06 06:22:41,412 - pytorch_modeler.py - INFO - Epoch 194/200:train_loss:148.390826, valid_AUC:0.516689, valid_pAUC:0.502579
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.34it/s]
# 2020-11-06 06:24:09,725 - pytorch_modeler.py - INFO - Epoch 195/200:train_loss:146.330306, valid_AUC:0.517600, valid_pAUC:0.502710
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.25it/s]
# 2020-11-06 06:25:38,077 - pytorch_modeler.py - INFO - Epoch 196/200:train_loss:144.285009, valid_AUC:0.517477, valid_pAUC:0.502720
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.26it/s]
# 2020-11-06 06:27:06,469 - pytorch_modeler.py - INFO - Epoch 197/200:train_loss:142.171250, valid_AUC:0.515966, valid_pAUC:0.502748
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.36it/s]
# 2020-11-06 06:28:34,866 - pytorch_modeler.py - INFO - Epoch 198/200:train_loss:140.271965, valid_AUC:0.517256, valid_pAUC:0.502654
# 100%|██████████| 102/102 [01:06<00:00,  1.53it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.27it/s]
# 2020-11-06 06:30:03,284 - pytorch_modeler.py - INFO - Epoch 199/200:train_loss:138.385630, valid_AUC:0.517142, valid_pAUC:0.502720
# 100%|██████████| 102/102 [01:06<00:00,  1.54it/s]
# 100%|██████████| 1803/1803 [00:21<00:00, 82.00it/s]
# 2020-11-06 06:31:31,693 - pytorch_modeler.py - INFO - Epoch 200/200:train_loss:136.131792, valid_AUC:0.516703, valid_pAUC:0.502776
# 2020-11-06 06:31:33,736 - 00_train.py - INFO -
#  success:fan
# model_out_path ==>
#  /media/hiroki/working/research/dcase2020/result/2D/LSTM_VAE/models/fan_model.pth
# elapsed time: 17702.297129393 [sec]
# 2020-11-06 06:31:35,525 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2020-11-06 06:31:35,526 - 00_train.py - INFO - MAKE DATA_LOADER
# 2020-11-06 06:31:35,529 - 00_train.py - INFO - TRAINING
#   0%|          | 0/91 [00:00<?, ?it/s]
# use: cuda:0
#   1%|          | 1/91 [00:02<03:49,  2.55s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-6a6a79f8498a> in <module>
#       1 for machine_type in machine_types:
# ----> 2     history = run(machine_type)
#       3     with open('{}/{}_history.pkl'.format(PKL_DIR, machine_type), 'wb') as file:
#       4         pickle.dump(history , file)
#
# <ipython-input-9-499ee019c66d> in run(machine_type)
#      25     criterion = nn.MSELoss()
#      26     num_epochs = config['fit']['num_epochs']
# ---> 27     history = modeler.train_net(net, dataloaders_dict, criterion, optimizer, num_epochs, writer)
#      28     # output
#      29     model = history['model']
#
# /media/hiroki/working/research/dcase2020/2D_codes/LSTM_AEs/LSTM_VAE/pytorch_modeler.py in train_net(net, dataloaders_dict, criterion, optimizer, num_epochs, writer)
#     161                         # 訓練時はbackprop
#     162                         if phase == 'train':
# --> 163                             loss.backward()
#     164                             optimizer.step()
#     165                             # loss
#
# ~/anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# RuntimeError: CUDA out of memory. Tried to allocate 256.00 MiB (GPU 0; 5.93 GiB total capacity; 4.46 GiB already allocated; 96.19 MiB free; 4.65 GiB reserved in total by PyTorch)
# Exception raised from malloc at /opt/conda/conda-bld/pytorch_1595629427478/work/c10/cuda/CUDACachingAllocator.cpp:272 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::string) + 0x4d (0x7fbaf3d6477d in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0x20626 (0x7fbaf3fbc626 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libc10_cuda.so)
# frame #2: <unknown function> + 0x214f4 (0x7fbaf3fbd4f4 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libc10_cuda.so)
# frame #3: <unknown function> + 0x21b81 (0x7fbaf3fbdb81 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libc10_cuda.so)
# frame #4: at::native::empty_cuda(c10::ArrayRef<long>, c10::TensorOptions const&, c10::optional<c10::MemoryFormat>) + 0x249 (0x7fbaf6ebee39 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so)
# frame #5: <unknown function> + 0xd15c49 (0x7fbaf4edfc49 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so)
# frame #6: <unknown function> + 0xd2fa77 (0x7fbaf4ef9a77 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so)
# frame #7: <unknown function> + 0xe450dd (0x7fbb2b3040dd in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #8: <unknown function> + 0xe453f7 (0x7fbb2b3043f7 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #9: at::empty(c10::ArrayRef<long>, c10::TensorOptions const&, c10::optional<c10::MemoryFormat>) + 0xfa (0x7fbb2b40ee7a in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #10: at::native::empty_like(at::Tensor const&, c10::TensorOptions const&, c10::optional<c10::MemoryFormat>) + 0x49e (0x7fbb2b08d09e in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #11: <unknown function> + 0xfe3521 (0x7fbb2b4a2521 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #12: <unknown function> + 0x101ecc3 (0x7fbb2b4ddcc3 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #13: at::empty_like(at::Tensor const&, c10::TensorOptions const&, c10::optional<c10::MemoryFormat>) + 0x101 (0x7fbb2b3f1f91 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #14: at::native::zeros_like(at::Tensor const&, c10::TensorOptions const&, c10::optional<c10::MemoryFormat>) + 0x46 (0x7fbb2b086b56 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #15: <unknown function> + 0xfe6894 (0x7fbb2b4a5894 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #16: <unknown function> + 0x101ecc3 (0x7fbb2b4ddcc3 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #17: at::zeros_like(at::Tensor const&, c10::TensorOptions const&, c10::optional<c10::MemoryFormat>) + 0x101 (0x7fbb2b3f2231 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #18: at::native::avg_pool2d_backward_cuda(at::Tensor const&, at::Tensor const&, c10::ArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, bool, bool, c10::optional<long>) + 0x6d (0x7fbaf5a1a91d in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so)
# frame #19: <unknown function> + 0xd0fd19 (0x7fbaf4ed9d19 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so)
# frame #20: <unknown function> + 0xd31f9d (0x7fbaf4efbf9d in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so)
# frame #21: at::avg_pool2d_backward(at::Tensor const&, at::Tensor const&, c10::ArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, bool, bool, c10::optional<long>) + 0x1e7 (0x7fbb2b401e07 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #22: <unknown function> + 0x2ba17ce (0x7fbb2d0607ce in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #23: <unknown function> + 0xe6fbbd (0x7fbb2b32ebbd in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #24: at::avg_pool2d_backward(at::Tensor const&, at::Tensor const&, c10::ArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, bool, bool, c10::optional<long>) + 0x1e7 (0x7fbb2b401e07 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #25: torch::autograd::generated::AvgPool2DBackward::apply(std::vector<at::Tensor, std::allocator<at::Tensor> >&&) + 0x1a9 (0x7fbb2cf5fc59 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #26: <unknown function> + 0x30d1017 (0x7fbb2d590017 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #27: torch::autograd::Engine::evaluate_function(std::shared_ptr<torch::autograd::GraphTask>&, torch::autograd::Node*, torch::autograd::InputBuffer&, std::shared_ptr<torch::autograd::ReadyQueue> const&) + 0x1400 (0x7fbb2d58b860 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #28: torch::autograd::Engine::thread_main(std::shared_ptr<torch::autograd::GraphTask> const&) + 0x451 (0x7fbb2d58c401 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #29: torch::autograd::Engine::thread_init(int, std::shared_ptr<torch::autograd::ReadyQueue> const&, bool) + 0x89 (0x7fbb2d584579 in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cpu.so)
# frame #30: torch::autograd::python::PythonEngine::thread_init(int, std::shared_ptr<torch::autograd::ReadyQueue> const&, bool) + 0x4a (0x7fbb318b399a in /home/hiroki/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_python.so)
# frame #31: <unknown function> + 0xc819d (0x7fbb75ca819d in /home/hiroki/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/../../../../.././libstdc++.so.6)
# frame #32: <unknown function> + 0x76db (0x7fbb78c3a6db in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #33: clone + 0x3f (0x7fbb78963a3f in /lib/x86_64-linux-gnu/libc.so.6)

# %% [markdown]
# history = run('ToyCar')
# with open('{}/{}_history.pkl'.format(PKL_DIR, machine_type), 'wb') as file:
#     pickle.dump(history , file)

# %% [raw]
# history['reconstruct_img']['label']
