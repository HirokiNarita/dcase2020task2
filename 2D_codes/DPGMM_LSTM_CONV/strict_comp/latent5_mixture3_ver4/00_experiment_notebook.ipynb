# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})
import mlflow
from collections import defaultdict
from scipy.stats import zscore

# original library

import common as com
import pytorch_modeler as modeler
from pytorch_model import DAGMM as Model
from pytorch_utils import filtered_load_model
import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
#with open("./config.yaml", 'rb') as f:
#    config = yaml.load(f)

log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')
# Out:
# /home/hiroki/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_path = INPUT_ROOT + "/dev_data"
add_dev_path = INPUT_ROOT + "/add_dev_data"
# machine type
MACHINE_TYPE = config['IO_OPTION']['MACHINE_TYPE']
machine_types = os.listdir(dev_path)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
PKL_DIR = OUTPUT_ROOT + '/pkl'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(PKL_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/working/research/dcase2020/result/2D/DAGMM/strict_comp/latent5_mixture3_ver4/config.yaml'

# %% [markdown]
# ## make path list and train/valid split

# %%
############################################################################
# make path set and train/valid split
############################################################################
'''
train_paths[machine_type]['train' or 'valid'] = path
'''
dev_train_paths = {}
add_train_paths = {}
train_paths = {}

# %%
for machine_type in machine_types:
    # dev train
    dev_train_paths = ["{}/{}/train/".format(dev_path, machine_type) + file for file in os.listdir("{}/{}/train".format(dev_path, machine_type))]
    dev_train_paths = sorted(dev_train_paths)
    # add_dev train
    add_train_paths = ["{}/{}/train/".format(add_dev_path, machine_type) + file for file in os.listdir("{}/{}/train".format(add_dev_path, machine_type))]
    add_train_paths = sorted(add_train_paths)
    # valid
    dev_valid_paths = ["{}/{}/test/".format(dev_path, machine_type) + file for file in os.listdir("{}/{}/test".format(dev_path, machine_type))]
    dev_valid_paths = sorted(dev_valid_paths)
    
    train_paths[machine_type] = {}
    train_paths[machine_type]['train'] = dev_train_paths + add_train_paths
    train_paths[machine_type]['valid'] = dev_valid_paths

# %% [raw]
# # for machine_type in machine_types:
#     # dev train
#     dev_train_all_paths = ["{}/{}/train/".format(dev_path, machine_type) + file for file in os.listdir("{}/{}/train".format(dev_path, machine_type))]
#     dev_train_all_paths = sorted(dev_train_all_paths)
#     dev_train_paths[machine_type] = {}
#     dev_train_paths[machine_type]['train'], \
#     dev_train_paths[machine_type]['valid'] = train_test_split(dev_train_all_paths,
#                                                               test_size=config['etc']['test_size'],
#                                                               shuffle=False,
#                                                              )
#     # add_dev train
#     add_train_all_paths = ["{}/{}/train/".format(add_dev_path, machine_type) + file for file in os.listdir("{}/{}/train".format(add_dev_path, machine_type))]
#     add_train_all_paths = sorted(add_train_all_paths)
#     add_train_paths[machine_type] = {}
#     add_train_paths[machine_type]['train'], \
#     add_train_paths[machine_type]['valid'] = train_test_split(add_train_all_paths,
#                                                               test_size=config['etc']['test_size'],
#                                                               shuffle=False,
#                                                              )
#     train_paths[machine_type] = {}
#     train_paths[machine_type]['train'] = dev_train_paths[machine_type]['train'] + add_train_paths[machine_type]['train']
#     train_paths[machine_type]['valid'] = dev_train_paths[machine_type]['valid'] + add_train_paths[machine_type]['valid']

# %% [markdown]
# ## training

# %%
#############################################################################
# run
#############################################################################
def run(machine_type):
    com.tic()
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(train_paths, machine_type)
    # define writer for tensorbord
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)         # debug
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    logger.info('TRAINING')
    # parameter setting
    net = Model(sample_rate=config['preprocessing']['sample_rate'],
                window_size=config['preprocessing']['window_size'],
                hop_size=config['preprocessing']['hop_size'],
                mel_bins=config['preprocessing']['mel_bins'],
                fmin=config['preprocessing']['fmin'],
                fmax=config['preprocessing']['fmax'],
                latent_size=config['fit']['latent_size'],
                mixture_size=config['fit']['mixture_size'])
    #pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_PATH'])
    #net = filtered_load_model(net, pretrained_dict)
    optimizer = optim.Adam(net.parameters(), lr=1e-3)
    num_epochs = config['fit']['num_epochs']
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e2, 
                                              max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    criterion = nn.MSELoss()
    #try:
    history = modeler.train_net(net, dataloaders_dict, criterion, optimizer, scheduler, num_epochs, writer)
    # output
    model = history['model']
    gmm_param = history['gmm_param']
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    gmm_param_path = MODEL_DIR+'/{}_gmm_param.pkl'.format(machine_type)
    torch.save(model.state_dict(), model_out_path)
    logger.info('\n success:{0} \n'.format(machine_type) + \
                    'model_out_path ==> \n {0}'.format(model_out_path))
    pd.to_pickle(gmm_param, gmm_param_path)
    #  close writer for tensorbord
    writer.close()
    #modeler.mlflow_log(history, config, machine_type, model_out_path, tb_log_dir)
    com.toc()
    #except:
    #    print("error")
    #    history = "error"
    return history

# %%
machine_types
# Out:
# ['fan', 'pump', 'slider', 'ToyCar', 'ToyConveyor', 'valve']

# %%
for machine_type in machine_types:
    history = run(machine_type)
    #with open('{}/{}_history.pkl'.format(PKL_DIR, machine_type), 'wb') as file:
    #    pickle.dump(history , file)
# Out:
# 2020-12-01 16:14:13,267 - 00_train.py - INFO - TARGET MACHINE_TYPE: fan
# 2020-12-01 16:14:13,268 - 00_train.py - INFO - MAKE DATA_LOADER
# 2020-12-01 16:14:14,167 - 00_train.py - INFO - TRAINING
# use: cuda:0
# 100%|██████████| 51/51 [00:53<00:00,  1.05s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# 2020-12-01 16:15:12,518 - pytorch_modeler.py - INFO - Epoch 1/300:train_loss:47927.609192, tr_rec:47924.319763, tr_eng:2.958569, tr_covd:29934.387573, val_AUC:0.520980, val_pAUC:0.512351
# 100%|██████████| 51/51 [00:53<00:00,  1.05s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.45it/s]
# 2020-12-01 16:16:09,324 - pytorch_modeler.py - INFO - Epoch 2/300:train_loss:47592.411865, tr_rec:47591.816589, tr_eng:-18.192228, tr_covd:24146.577850, val_AUC:0.452042, val_pAUC:0.497252
# 100%|██████████| 51/51 [00:53<00:00,  1.05s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.45it/s]
# 2020-12-01 16:17:06,505 - pytorch_modeler.py - INFO - Epoch 3/300:train_loss:47224.187561, tr_rec:47227.175354, tr_eng:-48.612312, tr_covd:18734.677673, val_AUC:0.453156, val_pAUC:0.500966
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.48it/s]
# 2020-12-01 16:18:02,480 - pytorch_modeler.py - INFO - Epoch 4/300:train_loss:46858.334717, tr_rec:46863.287842, tr_eng:-65.457725, tr_covd:15922.282349, val_AUC:0.480045, val_pAUC:0.493482
# 100%|██████████| 51/51 [00:54<00:00,  1.07s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.20it/s]
# 2020-12-01 16:19:00,481 - pytorch_modeler.py - INFO - Epoch 5/300:train_loss:46470.389099, tr_rec:46476.260315, tr_eng:-73.913382, tr_covd:15198.711731, val_AUC:0.503017, val_pAUC:0.501791
# 100%|██████████| 51/51 [00:53<00:00,  1.05s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.31it/s]
# 2020-12-01 16:19:57,719 - pytorch_modeler.py - INFO - Epoch 6/300:train_loss:46024.042664, tr_rec:46031.744141, tr_eng:-91.986926, tr_covd:14970.595276, val_AUC:0.487514, val_pAUC:0.498199
# 100%|██████████| 51/51 [00:51<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# 2020-12-01 16:20:53,112 - pytorch_modeler.py - INFO - Epoch 7/300:train_loss:45512.650879, tr_rec:45521.442505, tr_eng:-102.873512, tr_covd:14958.513214, val_AUC:0.516226, val_pAUC:0.518513
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.47it/s]
# 2020-12-01 16:21:48,938 - pytorch_modeler.py - INFO - Epoch 8/300:train_loss:44954.174988, tr_rec:44962.307007, tr_eng:-96.837929, tr_covd:15521.056702, val_AUC:0.488945, val_pAUC:0.506443
# 100%|██████████| 51/51 [00:52<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# 2020-12-01 16:22:45,397 - pytorch_modeler.py - INFO - Epoch 9/300:train_loss:44291.571228, tr_rec:44301.481140, tr_eng:-114.453878, tr_covd:15355.592133, val_AUC:0.523968, val_pAUC:0.497759
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# 2020-12-01 17:04:53,004 - pytorch_modeler.py - INFO - Epoch 54/300:train_loss:367.349402, tr_rec:374.177763, tr_eng:-83.764400, tr_covd:15480.764465, val_AUC:0.476231, val_pAUC:0.499991
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.54it/s]
# 2020-12-01 17:05:48,705 - pytorch_modeler.py - INFO - Epoch 55/300:train_loss:365.811367, tr_rec:372.524500, tr_eng:-82.571987, tr_covd:15440.674683, val_AUC:0.461870, val_pAUC:0.503761
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.37it/s]
# 2020-12-01 17:06:43,898 - pytorch_modeler.py - INFO - Epoch 56/300:train_loss:361.046329, tr_rec:367.720904, tr_eng:-82.040975, tr_covd:15295.219604, val_AUC:0.463275, val_pAUC:0.501585
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# 2020-12-01 17:07:39,483 - pytorch_modeler.py - INFO - Epoch 57/300:train_loss:362.043517, tr_rec:369.166656, tr_eng:-86.623652, tr_covd:15392.256653, val_AUC:0.450709, val_pAUC:0.499015
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.40it/s]
# 2020-12-01 17:08:35,098 - pytorch_modeler.py - INFO - Epoch 58/300:train_loss:358.700065, tr_rec:366.032916, tr_eng:-89.027636, tr_covd:15699.165771, val_AUC:0.453676, val_pAUC:0.501594
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 17:09:30,718 - pytorch_modeler.py - INFO - Epoch 59/300:train_loss:359.306945, tr_rec:366.765992, tr_eng:-90.240778, tr_covd:15650.295410, val_AUC:0.478238, val_pAUC:0.496971
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.29it/s]
# 2020-12-01 17:10:25,780 - pytorch_modeler.py - INFO - Epoch 60/300:train_loss:357.020947, tr_rec:364.435560, tr_eng:-89.669683, tr_covd:15523.537415, val_AUC:0.459953, val_pAUC:0.498659
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.51it/s]
# 2020-12-01 17:11:21,247 - pytorch_modeler.py - INFO - Epoch 61/300:train_loss:357.374071, tr_rec:365.462419, tr_eng:-96.738479, tr_covd:15855.040070, val_AUC:0.455399, val_pAUC:0.502129
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 17:12:16,951 - pytorch_modeler.py - INFO - Epoch 62/300:train_loss:354.688524, tr_rec:362.716951, tr_eng:-96.111630, tr_covd:15827.350800, val_AUC:0.467742, val_pAUC:0.498809
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# 2020-12-01 17:13:12,500 - pytorch_modeler.py - INFO - Epoch 63/300:train_loss:353.392509, tr_rec:361.136598, tr_eng:-93.082295, tr_covd:15641.414734, val_AUC:0.464770, val_pAUC:0.497046
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.36it/s]
# 2020-12-01 17:14:07,712 - pytorch_modeler.py - INFO - Epoch 64/300:train_loss:352.088583, tr_rec:360.058857, tr_eng:-95.383518, tr_covd:15680.754669, val_AUC:0.456450, val_pAUC:0.498725
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# 2020-12-01 17:15:03,189 - pytorch_modeler.py - INFO - Epoch 65/300:train_loss:350.548747, tr_rec:358.766231, tr_eng:-98.153034, tr_covd:15978.198669, val_AUC:0.464227, val_pAUC:0.499812
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.49it/s]
# 2020-12-01 17:15:58,895 - pytorch_modeler.py - INFO - Epoch 66/300:train_loss:352.681623, tr_rec:360.934034, tr_eng:-98.341961, tr_covd:15817.838684, val_AUC:0.448264, val_pAUC:0.496417
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.51it/s]
# 2020-12-01 17:16:54,526 - pytorch_modeler.py - INFO - Epoch 67/300:train_loss:349.910601, tr_rec:358.105925, tr_eng:-97.634734, tr_covd:15681.493988, val_AUC:0.456383, val_pAUC:0.499934
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.41it/s]
# 2020-12-01 17:17:49,624 - pytorch_modeler.py - INFO - Epoch 68/300:train_loss:351.344806, tr_rec:359.779351, tr_eng:-100.824918, tr_covd:16479.510651, val_AUC:0.449654, val_pAUC:0.499193
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.49it/s]
# 2020-12-01 17:18:45,097 - pytorch_modeler.py - INFO - Epoch 69/300:train_loss:349.341247, tr_rec:357.649793, tr_eng:-99.073025, tr_covd:15987.570099, val_AUC:0.456723, val_pAUC:0.497186
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 17:19:40,826 - pytorch_modeler.py - INFO - Epoch 70/300:train_loss:348.620274, tr_rec:357.100852, tr_eng:-100.915164, tr_covd:16109.375061, val_AUC:0.453482, val_pAUC:0.497655
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# 2020-12-01 17:20:36,499 - pytorch_modeler.py - INFO - Epoch 71/300:train_loss:343.691891, tr_rec:352.430467, tr_eng:-103.404599, tr_covd:16018.838898, val_AUC:0.456450, val_pAUC:0.500188
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.57it/s]
# 2020-12-01 17:21:31,528 - pytorch_modeler.py - INFO - Epoch 72/300:train_loss:345.914496, tr_rec:354.797868, tr_eng:-104.848559, tr_covd:16014.861557, val_AUC:0.459148, val_pAUC:0.502973
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# 2020-12-01 17:22:27,054 - pytorch_modeler.py - INFO - Epoch 73/300:train_loss:344.538262, tr_rec:353.361603, tr_eng:-104.544429, tr_covd:16311.006744, val_AUC:0.454332, val_pAUC:0.498453
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# 2020-12-01 17:23:22,852 - pytorch_modeler.py - INFO - Epoch 74/300:train_loss:342.217539, tr_rec:351.261612, tr_eng:-106.453645, tr_covd:16012.914276, val_AUC:0.447086, val_pAUC:0.496868
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# 2020-12-01 17:24:18,422 - pytorch_modeler.py - INFO - Epoch 75/300:train_loss:345.364211, tr_rec:354.664311, tr_eng:-109.451444, tr_covd:16450.439331, val_AUC:0.451033, val_pAUC:0.500338
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.47it/s]
# 2020-12-01 17:25:13,502 - pytorch_modeler.py - INFO - Epoch 76/300:train_loss:343.791235, tr_rec:353.182903, tr_eng:-110.319373, tr_covd:16402.686798, val_AUC:0.456896, val_pAUC:0.498199
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# 2020-12-01 17:26:08,962 - pytorch_modeler.py - INFO - Epoch 77/300:train_loss:340.147886, tr_rec:349.651020, tr_eng:-111.602128, tr_covd:16570.777740, val_AUC:0.456142, val_pAUC:0.502429
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.54it/s]
# 2020-12-01 17:27:04,658 - pytorch_modeler.py - INFO - Epoch 78/300:train_loss:339.834569, tr_rec:349.324039, tr_eng:-111.370161, tr_covd:16475.446686, val_AUC:0.456146, val_pAUC:0.499709
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 17:28:00,287 - pytorch_modeler.py - INFO - Epoch 79/300:train_loss:340.785475, tr_rec:350.354196, tr_eng:-111.878024, tr_covd:16190.830627, val_AUC:0.452498, val_pAUC:0.503386
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.37it/s]
# 2020-12-01 17:28:55,434 - pytorch_modeler.py - INFO - Epoch 80/300:train_loss:340.049562, tr_rec:349.617476, tr_eng:-112.166375, tr_covd:16487.235809, val_AUC:0.457354, val_pAUC:0.500863
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# 2020-12-01 17:29:51,065 - pytorch_modeler.py - INFO - Epoch 81/300:train_loss:338.696185, tr_rec:348.826685, tr_eng:-117.947094, tr_covd:16642.091949, val_AUC:0.468589, val_pAUC:0.500563
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.51it/s]
# 2020-12-01 17:30:46,592 - pytorch_modeler.py - INFO - Epoch 82/300:train_loss:339.286709, tr_rec:349.271570, tr_eng:-116.538198, tr_covd:16689.595428, val_AUC:0.459489, val_pAUC:0.495292
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# 2020-12-01 17:31:42,299 - pytorch_modeler.py - INFO - Epoch 83/300:train_loss:342.455380, tr_rec:352.376504, tr_eng:-115.955258, tr_covd:16744.025696, val_AUC:0.465504, val_pAUC:0.503151
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.42it/s]
# 2020-12-01 17:32:37,435 - pytorch_modeler.py - INFO - Epoch 84/300:train_loss:336.922421, tr_rec:346.588567, tr_eng:-113.034183, tr_covd:16372.723526, val_AUC:0.459045, val_pAUC:0.500994
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 17:33:32,937 - pytorch_modeler.py - INFO - Epoch 85/300:train_loss:334.560458, tr_rec:345.238060, tr_eng:-123.807933, tr_covd:17031.886230, val_AUC:0.465178, val_pAUC:0.500975
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.59it/s]
# 2020-12-01 17:34:28,586 - pytorch_modeler.py - INFO - Epoch 86/300:train_loss:335.996700, tr_rec:346.498270, tr_eng:-121.965640, tr_covd:16949.939148, val_AUC:0.461880, val_pAUC:0.499212
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.48it/s]
# 2020-12-01 17:35:24,313 - pytorch_modeler.py - INFO - Epoch 87/300:train_loss:335.659993, tr_rec:346.374662, tr_eng:-124.383789, tr_covd:17237.106995, val_AUC:0.466053, val_pAUC:0.498650
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.57it/s]
# 2020-12-01 17:36:19,394 - pytorch_modeler.py - INFO - Epoch 88/300:train_loss:336.155032, tr_rec:346.727362, tr_eng:-122.616876, tr_covd:16893.585938, val_AUC:0.462145, val_pAUC:0.498715
# 100%|██████████| 51/51 [00:54<00:00,  1.08s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.22it/s]
# 2020-12-01 17:37:17,867 - pytorch_modeler.py - INFO - Epoch 89/300:train_loss:333.814012, tr_rec:344.461517, tr_eng:-123.235670, tr_covd:16760.628693, val_AUC:0.460374, val_pAUC:0.500506
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# 2020-12-01 17:38:13,675 - pytorch_modeler.py - INFO - Epoch 90/300:train_loss:333.141224, tr_rec:343.952915, tr_eng:-125.325462, tr_covd:17208.552094, val_AUC:0.463831, val_pAUC:0.500703
# 100%|██████████| 51/51 [00:52<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.31it/s]
# 2020-12-01 17:39:10,055 - pytorch_modeler.py - INFO - Epoch 91/300:train_loss:336.402906, tr_rec:347.122032, tr_eng:-123.967113, tr_covd:16775.837555, val_AUC:0.456222, val_pAUC:0.500732
# 100%|██████████| 51/51 [00:52<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.27it/s]
# 2020-12-01 17:40:05,816 - pytorch_modeler.py - INFO - Epoch 92/300:train_loss:331.428125, tr_rec:342.520352, tr_eng:-127.914781, tr_covd:16992.506042, val_AUC:0.446078, val_pAUC:0.498762
# 100%|██████████| 51/51 [00:53<00:00,  1.06s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.27it/s]
# 2020-12-01 17:41:03,304 - pytorch_modeler.py - INFO - Epoch 93/300:train_loss:334.973275, tr_rec:346.249550, tr_eng:-129.927414, tr_covd:17164.697266, val_AUC:0.461399, val_pAUC:0.500900
# 100%|██████████| 51/51 [00:54<00:00,  1.06s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.17it/s]
# 2020-12-01 17:42:00,981 - pytorch_modeler.py - INFO - Epoch 94/300:train_loss:331.873621, tr_rec:343.222913, tr_eng:-131.062490, tr_covd:17569.530365, val_AUC:0.464536, val_pAUC:0.499208
# 100%|██████████| 51/51 [00:53<00:00,  1.05s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.23it/s]
# 2020-12-01 17:42:58,217 - pytorch_modeler.py - INFO - Epoch 95/300:train_loss:333.755794, tr_rec:344.732060, tr_eng:-126.878527, tr_covd:17115.873505, val_AUC:0.460476, val_pAUC:0.500722
# 100%|██████████| 51/51 [00:53<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.48it/s]
# 2020-12-01 17:43:54,197 - pytorch_modeler.py - INFO - Epoch 96/300:train_loss:329.809532, tr_rec:341.116508, tr_eng:-129.928911, tr_covd:16859.151855, val_AUC:0.465554, val_pAUC:0.498968
# 100%|██████████| 51/51 [00:53<00:00,  1.05s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# 2020-12-01 17:44:51,278 - pytorch_modeler.py - INFO - Epoch 97/300:train_loss:329.667684, tr_rec:341.153361, tr_eng:-131.896780, tr_covd:17040.019012, val_AUC:0.461099, val_pAUC:0.503470
# 100%|██████████| 51/51 [00:52<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.26it/s]
# 2020-12-01 17:45:47,749 - pytorch_modeler.py - INFO - Epoch 98/300:train_loss:332.202348, tr_rec:344.052761, tr_eng:-135.759059, tr_covd:17254.927521, val_AUC:0.458474, val_pAUC:0.497383
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.24it/s]
# 2020-12-01 17:46:44,026 - pytorch_modeler.py - INFO - Epoch 99/300:train_loss:332.667353, tr_rec:344.159127, tr_eng:-132.242698, tr_covd:17324.935455, val_AUC:0.463858, val_pAUC:0.497637
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.68it/s]
# 2020-12-01 17:47:39,290 - pytorch_modeler.py - INFO - Epoch 100/300:train_loss:328.871655, tr_rec:340.451285, tr_eng:-132.984205, tr_covd:17187.899658, val_AUC:0.456878, val_pAUC:0.502495
# 100%|██████████| 51/51 [00:57<00:00,  1.12s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.44it/s]
# 2020-12-01 17:48:39,778 - pytorch_modeler.py - INFO - Epoch 101/300:train_loss:327.509273, tr_rec:339.096539, tr_eng:-132.793067, tr_covd:16920.425629, val_AUC:0.457671, val_pAUC:0.501519
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# 2020-12-01 17:49:35,374 - pytorch_modeler.py - INFO - Epoch 102/300:train_loss:327.099477, tr_rec:339.160110, tr_eng:-137.855213, tr_covd:17248.915405, val_AUC:0.461524, val_pAUC:0.500084
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 17:50:31,105 - pytorch_modeler.py - INFO - Epoch 103/300:train_loss:329.158946, tr_rec:341.061238, tr_eng:-136.082166, tr_covd:17059.220856, val_AUC:0.474556, val_pAUC:0.502223
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.74it/s]
# 2020-12-01 17:51:26,091 - pytorch_modeler.py - INFO - Epoch 104/300:train_loss:327.992178, tr_rec:339.761978, tr_eng:-134.789151, tr_covd:17091.174652, val_AUC:0.465190, val_pAUC:0.500450
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.51it/s]
# 2020-12-01 17:52:21,901 - pytorch_modeler.py - INFO - Epoch 105/300:train_loss:326.699916, tr_rec:338.731454, tr_eng:-137.476936, tr_covd:17161.553802, val_AUC:0.458558, val_pAUC:0.500703
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 17:53:17,717 - pytorch_modeler.py - INFO - Epoch 106/300:train_loss:325.639869, tr_rec:338.198523, tr_eng:-143.340152, tr_covd:17753.615326, val_AUC:0.453296, val_pAUC:0.498800
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# 2020-12-01 17:54:13,569 - pytorch_modeler.py - INFO - Epoch 107/300:train_loss:325.225283, tr_rec:337.906261, tr_eng:-143.923412, tr_covd:17113.639099, val_AUC:0.473614, val_pAUC:0.499672
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.74it/s]
# 2020-12-01 17:55:08,434 - pytorch_modeler.py - INFO - Epoch 108/300:train_loss:323.905786, tr_rec:337.232070, tr_eng:-151.242529, tr_covd:17979.682098, val_AUC:0.462307, val_pAUC:0.500994
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# 2020-12-01 17:56:04,559 - pytorch_modeler.py - INFO - Epoch 109/300:train_loss:324.002600, tr_rec:337.149199, tr_eng:-148.919015, tr_covd:17452.996368, val_AUC:0.471392, val_pAUC:0.500919
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.48it/s]
# 2020-12-01 17:57:00,191 - pytorch_modeler.py - INFO - Epoch 110/300:train_loss:324.985191, tr_rec:338.040354, tr_eng:-148.290667, tr_covd:17739.037537, val_AUC:0.463174, val_pAUC:0.493173
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.51it/s]
# 2020-12-01 17:57:55,813 - pytorch_modeler.py - INFO - Epoch 111/300:train_loss:321.937114, tr_rec:335.337602, tr_eng:-151.530197, tr_covd:17525.316711, val_AUC:0.458700, val_pAUC:0.499334
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.57it/s]
# 2020-12-01 17:58:50,827 - pytorch_modeler.py - INFO - Epoch 112/300:train_loss:321.599451, tr_rec:335.110221, tr_eng:-153.005122, tr_covd:17897.419373, val_AUC:0.459296, val_pAUC:0.497055
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.51it/s]
# 2020-12-01 17:59:46,587 - pytorch_modeler.py - INFO - Epoch 113/300:train_loss:322.070102, tr_rec:335.405679, tr_eng:-151.426160, tr_covd:18070.383972, val_AUC:0.463077, val_pAUC:0.495358
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.49it/s]
# 2020-12-01 18:00:42,080 - pytorch_modeler.py - INFO - Epoch 114/300:train_loss:320.338221, tr_rec:334.110568, tr_eng:-155.472133, tr_covd:17748.676819, val_AUC:0.453316, val_pAUC:0.497262
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# 2020-12-01 18:01:37,672 - pytorch_modeler.py - INFO - Epoch 115/300:train_loss:321.960425, tr_rec:335.632044, tr_eng:-154.642344, tr_covd:17926.143311, val_AUC:0.468215, val_pAUC:0.496446
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.59it/s]
# 2020-12-01 18:02:32,744 - pytorch_modeler.py - INFO - Epoch 116/300:train_loss:322.912863, tr_rec:336.311002, tr_eng:-151.519974, tr_covd:17538.610992, val_AUC:0.465939, val_pAUC:0.500338
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 18:03:28,621 - pytorch_modeler.py - INFO - Epoch 117/300:train_loss:319.801093, tr_rec:333.801530, tr_eng:-158.231490, tr_covd:18227.095337, val_AUC:0.471341, val_pAUC:0.502748
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# 2020-12-01 18:04:24,353 - pytorch_modeler.py - INFO - Epoch 118/300:train_loss:319.458510, tr_rec:334.008713, tr_eng:-163.790368, tr_covd:18288.342896, val_AUC:0.464145, val_pAUC:0.501200
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 18:05:20,003 - pytorch_modeler.py - INFO - Epoch 119/300:train_loss:319.743431, tr_rec:334.365889, tr_eng:-164.479469, tr_covd:18254.882385, val_AUC:0.466624, val_pAUC:0.496915
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.84it/s]
# 2020-12-01 18:06:14,864 - pytorch_modeler.py - INFO - Epoch 120/300:train_loss:317.472320, tr_rec:332.519947, tr_eng:-169.427177, tr_covd:18950.912109, val_AUC:0.459116, val_pAUC:0.493557
# 100%|██████████| 51/51 [00:53<00:00,  1.05s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 18:07:11,711 - pytorch_modeler.py - INFO - Epoch 121/300:train_loss:318.935393, tr_rec:333.786393, tr_eng:-166.520717, tr_covd:18010.714966, val_AUC:0.469003, val_pAUC:0.497369
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 18:08:07,411 - pytorch_modeler.py - INFO - Epoch 122/300:train_loss:318.891203, tr_rec:333.613296, tr_eng:-165.899843, tr_covd:18678.917419, val_AUC:0.466834, val_pAUC:0.502185
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 18:09:03,086 - pytorch_modeler.py - INFO - Epoch 123/300:train_loss:316.815431, tr_rec:332.127542, tr_eng:-171.310400, tr_covd:18189.328857, val_AUC:0.463786, val_pAUC:0.498762
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.66it/s]
# 2020-12-01 18:09:58,059 - pytorch_modeler.py - INFO - Epoch 124/300:train_loss:315.893614, tr_rec:332.029542, tr_eng:-180.691136, tr_covd:19331.855621, val_AUC:0.469081, val_pAUC:0.498978
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# 2020-12-01 18:10:53,804 - pytorch_modeler.py - INFO - Epoch 125/300:train_loss:315.404032, tr_rec:331.694766, tr_eng:-182.180018, tr_covd:19272.673828, val_AUC:0.472333, val_pAUC:0.497224
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# 2020-12-01 18:11:49,498 - pytorch_modeler.py - INFO - Epoch 126/300:train_loss:314.063068, tr_rec:330.104344, tr_eng:-179.678816, tr_covd:19266.059814, val_AUC:0.487724, val_pAUC:0.502420
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.51it/s]
# 2020-12-01 18:12:45,077 - pytorch_modeler.py - INFO - Epoch 127/300:train_loss:315.809954, tr_rec:331.887843, tr_eng:-179.796589, tr_covd:19017.689514, val_AUC:0.465849, val_pAUC:0.495949
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.60it/s]
# 2020-12-01 18:13:40,048 - pytorch_modeler.py - INFO - Epoch 128/300:train_loss:313.978347, tr_rec:330.582520, tr_eng:-185.388740, tr_covd:19346.995636, val_AUC:0.471684, val_pAUC:0.493641
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.41it/s]
# 2020-12-01 18:14:36,185 - pytorch_modeler.py - INFO - Epoch 129/300:train_loss:313.765145, tr_rec:330.112566, tr_eng:-182.427226, tr_covd:18952.993652, val_AUC:0.476229, val_pAUC:0.497524
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# 2020-12-01 18:15:31,822 - pytorch_modeler.py - INFO - Epoch 130/300:train_loss:312.330315, tr_rec:328.948334, tr_eng:-185.780368, tr_covd:19600.148651, val_AUC:0.467021, val_pAUC:0.499344
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.43it/s]
# 2020-12-01 18:16:27,667 - pytorch_modeler.py - INFO - Epoch 131/300:train_loss:311.965077, tr_rec:328.946836, tr_eng:-188.559732, tr_covd:18742.127686, val_AUC:0.468456, val_pAUC:0.498148
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.89it/s]
# 2020-12-01 18:17:22,431 - pytorch_modeler.py - INFO - Epoch 132/300:train_loss:312.308544, tr_rec:329.539125, tr_eng:-191.507382, tr_covd:19201.577576, val_AUC:0.469027, val_pAUC:0.495405
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# 2020-12-01 18:18:18,442 - pytorch_modeler.py - INFO - Epoch 133/300:train_loss:313.705400, tr_rec:331.066442, tr_eng:-192.960490, tr_covd:19350.080597, val_AUC:0.469383, val_pAUC:0.493698
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.49it/s]
# 2020-12-01 18:19:14,188 - pytorch_modeler.py - INFO - Epoch 134/300:train_loss:312.169564, tr_rec:329.484871, tr_eng:-192.404265, tr_covd:19251.191833, val_AUC:0.465793, val_pAUC:0.496352
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.55it/s]
# 2020-12-01 18:20:09,870 - pytorch_modeler.py - INFO - Epoch 135/300:train_loss:309.956590, tr_rec:327.895123, tr_eng:-200.112771, tr_covd:20727.436218, val_AUC:0.464506, val_pAUC:0.496905
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:02<00:00,  6.01it/s]
# 2020-12-01 18:21:04,642 - pytorch_modeler.py - INFO - Epoch 136/300:train_loss:312.572297, tr_rec:329.520189, tr_eng:-188.469367, tr_covd:18990.455383, val_AUC:0.463480, val_pAUC:0.493641
# 100%|██████████| 51/51 [00:53<00:00,  1.05s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.32it/s]
# 2020-12-01 18:22:01,799 - pytorch_modeler.py - INFO - Epoch 137/300:train_loss:307.908071, tr_rec:325.926434, tr_eng:-199.918516, tr_covd:19734.889099, val_AUC:0.471955, val_pAUC:0.491531
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 18:22:57,590 - pytorch_modeler.py - INFO - Epoch 138/300:train_loss:309.315386, tr_rec:327.587691, tr_eng:-203.122018, tr_covd:20398.974792, val_AUC:0.471131, val_pAUC:0.497172
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.48it/s]
# 2020-12-01 18:23:53,256 - pytorch_modeler.py - INFO - Epoch 139/300:train_loss:310.027975, tr_rec:328.075953, tr_eng:-200.260522, tr_covd:19780.756195, val_AUC:0.472192, val_pAUC:0.500713
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.86it/s]
# 2020-12-01 18:24:48,217 - pytorch_modeler.py - INFO - Epoch 140/300:train_loss:309.374402, tr_rec:327.634205, tr_eng:-202.945221, tr_covd:20347.190491, val_AUC:0.470645, val_pAUC:0.498406
# 100%|██████████| 51/51 [00:53<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.45it/s]
# 2020-12-01 18:25:44,623 - pytorch_modeler.py - INFO - Epoch 141/300:train_loss:308.023537, tr_rec:326.187706, tr_eng:-201.857921, tr_covd:20216.202484, val_AUC:0.471905, val_pAUC:0.499025
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.48it/s]
# 2020-12-01 18:26:40,254 - pytorch_modeler.py - INFO - Epoch 142/300:train_loss:308.086309, tr_rec:326.317110, tr_eng:-202.079531, tr_covd:19771.514160, val_AUC:0.470044, val_pAUC:0.501205
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# 2020-12-01 18:27:35,939 - pytorch_modeler.py - INFO - Epoch 143/300:train_loss:307.031003, tr_rec:325.232732, tr_eng:-201.600471, tr_covd:19583.182770, val_AUC:0.463191, val_pAUC:0.495855
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:02<00:00,  5.78it/s]
# 2020-12-01 18:28:30,721 - pytorch_modeler.py - INFO - Epoch 144/300:train_loss:306.514404, tr_rec:325.190665, tr_eng:-206.371010, tr_covd:19608.402191, val_AUC:0.471832, val_pAUC:0.496108
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.44it/s]
# 2020-12-01 18:29:26,647 - pytorch_modeler.py - INFO - Epoch 145/300:train_loss:306.237161, tr_rec:324.539249, tr_eng:-202.627508, tr_covd:19606.642487, val_AUC:0.473860, val_pAUC:0.494242
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# 2020-12-01 18:30:22,351 - pytorch_modeler.py - INFO - Epoch 146/300:train_loss:306.205706, tr_rec:325.506629, tr_eng:-213.978303, tr_covd:20969.072968, val_AUC:0.478930, val_pAUC:0.501280
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.40it/s]
# 2020-12-01 18:31:18,033 - pytorch_modeler.py - INFO - Epoch 147/300:train_loss:305.682620, tr_rec:324.816695, tr_eng:-212.514040, tr_covd:21173.303223, val_AUC:0.464537, val_pAUC:0.494992
# 100%|██████████| 51/51 [00:52<00:00,  1.02s/it]
# 100%|██████████| 15/15 [00:04<00:00,  3.25it/s]
# 2020-12-01 18:32:14,822 - pytorch_modeler.py - INFO - Epoch 148/300:train_loss:305.876886, tr_rec:324.969002, tr_eng:-211.637608, tr_covd:20716.436401, val_AUC:0.465034, val_pAUC:0.493815
# 100%|██████████| 51/51 [00:53<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# 2020-12-01 18:33:11,417 - pytorch_modeler.py - INFO - Epoch 149/300:train_loss:303.842973, tr_rec:322.804796, tr_eng:-209.503534, tr_covd:19885.306702, val_AUC:0.475891, val_pAUC:0.501125
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.38it/s]
# 2020-12-01 18:34:07,593 - pytorch_modeler.py - INFO - Epoch 150/300:train_loss:305.742134, tr_rec:324.614600, tr_eng:-209.313315, tr_covd:20588.655701, val_AUC:0.475172, val_pAUC:0.496263
# 100%|██████████| 51/51 [00:53<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.35it/s]
# 2020-12-01 18:35:04,219 - pytorch_modeler.py - INFO - Epoch 151/300:train_loss:305.748640, tr_rec:324.824040, tr_eng:-210.880483, tr_covd:20126.485229, val_AUC:0.468087, val_pAUC:0.493369
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.94it/s]
# 2020-12-01 18:35:59,825 - pytorch_modeler.py - INFO - Epoch 152/300:train_loss:302.793917, tr_rec:322.407736, tr_eng:-216.862929, tr_covd:20724.727203, val_AUC:0.476205, val_pAUC:0.493294
# 100%|██████████| 51/51 [00:53<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# 2020-12-01 18:36:56,368 - pytorch_modeler.py - INFO - Epoch 153/300:train_loss:302.924175, tr_rec:322.475056, tr_eng:-216.339967, tr_covd:20831.165924, val_AUC:0.474555, val_pAUC:0.491822
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.42it/s]
# 2020-12-01 18:37:52,430 - pytorch_modeler.py - INFO - Epoch 154/300:train_loss:303.239235, tr_rec:323.090374, tr_eng:-219.631185, tr_covd:21119.791870, val_AUC:0.470757, val_pAUC:0.494851
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.26it/s]
# 2020-12-01 18:38:48,564 - pytorch_modeler.py - INFO - Epoch 155/300:train_loss:302.225257, tr_rec:322.321416, tr_eng:-222.221113, tr_covd:21259.500946, val_AUC:0.468530, val_pAUC:0.497102
# 100%|██████████| 51/51 [00:53<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.96it/s]
# 2020-12-01 18:39:44,650 - pytorch_modeler.py - INFO - Epoch 156/300:train_loss:302.781196, tr_rec:322.251626, tr_eng:-215.511334, tr_covd:20807.016907, val_AUC:0.468784, val_pAUC:0.498152
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.20it/s]
# 2020-12-01 18:40:40,724 - pytorch_modeler.py - INFO - Epoch 157/300:train_loss:300.378645, tr_rec:320.480202, tr_eng:-222.794955, tr_covd:21779.398773, val_AUC:0.473492, val_pAUC:0.497548
# 100%|██████████| 51/51 [00:53<00:00,  1.04s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.12it/s]
# 2020-12-01 18:41:37,507 - pytorch_modeler.py - INFO - Epoch 158/300:train_loss:300.771587, tr_rec:320.298683, tr_eng:-215.646259, tr_covd:20375.291931, val_AUC:0.473477, val_pAUC:0.497876
# 100%|██████████| 51/51 [00:52<00:00,  1.03s/it]
# 100%|██████████| 15/15 [00:03<00:00,  4.44it/s]
# 2020-12-01 18:42:33,300 - pytorch_modeler.py - INFO - Epoch 159/300:train_loss:301.033240, tr_rec:321.205927, tr_eng:-222.959186, tr_covd:21232.309784, val_AUC:0.468208, val_pAUC:0.499681
#  65%|██████▍   | 33/51 [00:35<00:19,  1.07s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-b2d34d1d6174> in <module>
#       1 for machine_type in machine_types:
# ----> 2     history = run(machine_type)
#       3     #with open('{}/{}_history.pkl'.format(PKL_DIR, machine_type), 'wb') as file:
#       4     #    pickle.dump(history , file)
#
# <ipython-input-9-a93786db7f6b> in run(machine_type)
#      30     criterion = nn.MSELoss()
#      31     #try:
# ---> 32     history = modeler.train_net(net, dataloaders_dict, criterion, optimizer, scheduler, num_epochs, writer)
#      33     # output
#      34     model = history['model']
#
# /media/hiroki/working/research/dcase2020/2D_codes/DPGMM_LSTM_CONV/strict_comp/latent5_mixture3_ver4/pytorch_modeler.py in train_net(net, dataloaders_dict, criterion, optimizer, scheduler, num_epochs, writer)
#     157                     input = sample['feature']
#     158                     input = to_var(input)
# --> 159                     net, total_loss, sample_energy, recon_error, cov_diag = dagmm_step(net, input, optimizer, scheduler, device)
#     160                     tr_losses += total_loss.data.item()
#     161                     tr_eng += sample_energy.item()
#
# /media/hiroki/working/research/dcase2020/2D_codes/DPGMM_LSTM_CONV/strict_comp/latent5_mixture3_ver4/pytorch_modeler.py in dagmm_step(net, input_data, optimizer, scheduler, device)
#     260     net.zero_grad()
#     261     total_loss = torch.clamp(total_loss, max=1e7)
# --> 262     total_loss.backward()
#     263     torch.nn.utils.clip_grad_norm_(net.parameters(), 5)
#     264     optimizer.step()
#
# ~/anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# KeyboardInterrupt:

# %% [markdown]
# history = run('ToyCar')
# with open('{}/{}_history.pkl'.format(PKL_DIR, machine_type), 'wb') as file:
#     pickle.dump(history , file)

# %% [raw]
# history['reconstruct_img']['label']
